# %%
import re
import math

import certstream
import tqdm
import yaml
import time
import os
from Levenshtein import distance
from termcolor import colored, cprint
from tld import get_tld

# %%
def entropy(string):
    """Calculates the Shannon entropy of a string"""
    prob = [ float(string.count(c)) / len(string) for c in dict.fromkeys(list(string)) ] # probabilities of chars
    print(prob)
    entropy = - sum([ p * math.log(p) / math.log(2.0) for p in prob ])
    return entropy

# %%
var = "sssskkkk"

res = entropy(var)

print("res: ", res)
print("log", math.log(math.exp(1)))
for c in dict.fromkeys(list(var)):
    print(c) 
# print("Count:", var.count(c))
# Out:
# [0.5, 0.5]
# res:  1.0
# log 1.0
# s
# k

# %%
for i in tqdm.tqdm(range(1,10)):
    print("i:", i)


#suspicious_yaml = os.path.dirname(os.path.realpath(__file__))+'/suspicious.yaml'
import os
print("file:",__file__)
#print("sus:", suspicious_yaml)
# Out:
# 100%|██████████| 9/9 [00:00<00:00, 51710.60it/s]
# i: 1
# i: 2
# i: 3
# i: 4
# i: 5
# i: 6
# i: 7
# i: 8
# i: 9
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 7
#       5 #suspicious_yaml = os.path.dirname(os.path.realpath(__file__))+'/suspicious.yaml'
#       6 import os
# ----> 7 print("file:",__file__)
#       8 #print("sus:", suspicious_yaml)
#
# NameError: name '__file__' is not defined

# %%
words_in_domain = re.split("\W+", "domain.com.fi")
print(words_in_domain)
# Out:
# ['domain', 'com', 'fi']
# <>:1: SyntaxWarning: invalid escape sequence '\W'
# <>:1: SyntaxWarning: invalid escape sequence '\W'
# /var/folders/dw/2p1g8d754ygdc7vnzvm1kxd80000gn/T/ipykernel_9167/1749204505.py:1: SyntaxWarning: invalid escape sequence '\W'
#   words_in_domain = re.split("\W+", "domain.com.fi")

# %%
import re

def find_ip_addresses(input_string):
    # Regular expression for IPv4 addresses
    ipv4_pattern = r'((25[0-5]|2[0-4][0-9]|1[0-9]{2}|[1-9]?[0-9])\.){3}(25[0-5]|2[0-4][0-9]|1[0-9]{2}|[1-9]?[0-9])'

    # Regular expression for simplified IPv6 addresses
    ipv6_pattern = r'\b(?:[a-fA-F0-9]{1,4}:){7}[a-fA-F0-9]{1,4}\b'

    # Combine both patterns
    ip_pattern = f'({ipv4_pattern})|({ipv6_pattern})'

    # Find all matches
    matches = re.findall(ip_pattern, input_string)

    # Extract IPv4 and IPv6 addresses from matches
    ip_addresses = [match[0] if match[0] else match[1] for match in matches]

    return ip_addresses

# Example usage

user_input = input("Enter a string to search for IP addresses: ")
ip_addresses = find_ip_addresses(user_input)

if ip_addresses:
    print("Found IP addresses:")
    for ip in ip_addresses:
        print(ip)
else:
    print("No IP addresses found.")

# CompletedProcess(args=['./zdns/zdns', 'A', '"*.s3-control.eu-central-2.amazonaws.com"', '--verbosity=1'], returncode=0, 
#                  stdout=b'{"name":"*.s3-control.eu-central-2.amazonaws.com",
#                  "results":{"A":{"data":{"additionals":[{"flags":"","type":"EDNS0","udpsize":1232,"version":0}],
#                                          "answers":[{"answer":"s3-r-w.eu-central-2.amazonaws.com.","class":"IN","name":"*.s3-control.eu-central-2.amazonaws.com","ttl":300,"type":"CNAME"},
#                                                     {"answer":"52.95.141.7","class":"IN","name":"s3-r-w.eu-central-2.amazonaws.com","ttl":300,"type":"A"},
#                                                     {"answer":"3.5.54.35","class":"IN","name":"s3-r-w.eu-central-2.amazonaws.com","ttl":300,"type":"A"}],"protocol":"udp","resolver":"10.245.0.1:53"},"duration":0.019667333,"status":"NOERROR","timestamp":"2025-01-12T21:11:50+01:00"}}}\n', 
#                  stderr=b'00h:00m:00s; Scan Complete; 1 names scanned; 50.37 names/sec; 100.0% success rate; NOERROR: 1\n')
# Out:
# Found IP addresses:
# 52.95.141.7
# 3.5.54.35
# 10.245.0.1

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import sys
import os

def take_screenshot(ip_address, output_file="screenshot.png"):
    # Validate IP address format
    import re
    ipv4_pattern = r'\b((25[0-5]|2[0-4][0-9]|1[0-9]{2}|[1-9]?[0-9])\.){3}(25[0-5]|2[0-4][0-9]|1[0-9]{2}|[1-9]?[0-9])\b'
    if not re.match(ipv4_pattern, ip_address):
        print("Invalid IP address format.")
        return

    # Prepare Chrome options
    chrome_options = Options()
    chrome_options.add_argument("--headless")  # Run browser in headless mode (no GUI)
    chrome_options.add_argument("--disable-gpu")  # Disable GPU for better compatibility
    chrome_options.add_argument("--window-size=1920,1080")  # Set window size

    # Set up the Chrome WebDriver
    service = Service("./chromedriver")  # Replace "chromedriver" with the path to your ChromeDriver if necessary
    driver = webdriver.Chrome(service=service, options=chrome_options)

    try:
        # Construct the URL
        url = f"http://{ip_address}"
        print(f"Accessing {url}...")
        
        # Open the website
        driver.get(url)

        # Wait for the page to load completely
        driver.implicitly_wait(10)

        # Take a screenshot
        screenshot_path = os.path.abspath(output_file)
        driver.save_screenshot(screenshot_path)
        print(f"Screenshot saved as: {screenshot_path}")
    
    except Exception as e:
        print(f"An error occurred: {e}")
    
    finally:
        driver.quit()

take_screenshot("172.217.20.174")
# Out:
# Accessing http://172.217.20.174...
# Screenshot saved as: /Users/santerikokkonen/Desktop/SecIntro/project/Certificate-transparency/screenshot.png

# %%
r = "asd" + "asd"
print(r)
# Out:
# asdasd
